# %%
# !pip install langchain openai langchain-openai langchain-community -q

# %%
from getpass import getpass

# %% [markdown]
# ## Если используете ключ от OpenAI, запустите эту ячейку 👇

# %%
import os
from langchain_openai import ChatOpenAI


# os.environ['OPENAI_API_KEY'] = "Введите ваш OpenAI API ключ"
os.environ['OPENAI_API_KEY'] = getpass(prompt='Введите ваш OpenAI API ключ')

# Инициализируем языковую модель
llm = ChatOpenAI(temperature=0.0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4248202096.py in <cell line: 0>()
#       1 import os
# ----> 2 from langchain_openai import ChatOpenAI
#       3
#       4
#       5 # os.environ['OPENAI_API_KEY'] = "Введите ваш OpenAI API ключ"
#
# /usr/local/lib/python3.12/dist-packages/langchain_openai/__init__.py in <module>
# ----> 1 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       2 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#       3 from langchain_openai.llms import AzureOpenAI, OpenAI
#       4 from langchain_openai.tools import custom_tool
#       5
#
# /usr/local/lib/python3.12/dist-packages/langchain_openai/chat_models/__init__.py in <module>
# ----> 1 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       2 from langchain_openai.chat_models.base import ChatOpenAI
#       3
#       4 __all__ = ["ChatOpenAI", "AzureChatOpenAI"]
#
# /usr/local/lib/python3.12/dist-packages/langchain_openai/chat_models/azure.py in <module>
#       9
#      10 import openai
# ---> 11 from langchain_core.language_models import LanguageModelInput
#      12 from langchain_core.language_models.chat_models import LangSmithParams
#      13 from langchain_core.messages import BaseMessage
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/__init__.py in __getattr__(attr_name)
#     110 def __getattr__(attr_name: str) -> object:
#     111     module_name = _dynamic_imports.get(attr_name)
# --> 112     result = import_attr(attr_name, module_name, __spec__.parent)
#     113     globals()[attr_name] = result
#     114     return result
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/_import_utils.py in import_attr(attr_name, module_name, package)
#      34     else:
#      35         try:
# ---> 36             module = import_module(f".{module_name}", package=package)
#      37         except ModuleNotFoundError as err:
#      38             msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/base.py in <module>
#      42
#      43 try:
# ---> 44     from transformers import GPT2TokenizerFast  # type: ignore[import-not-found]
#      45
#      46     _HAS_TRANSFORMERS = True
#
# /usr/local/lib/python3.12/dist-packages/transformers/__init__.py in <module>
#      25
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.12/dist-packages/transformers/dependency_versions_check.py in <module>
#      14
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      17
#      18
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/__init__.py in <module>
#      22
#      23 from .. import __version__
# ---> 24 from .auto_docstring import (
#      25     ClassAttrs,
#      26     ClassDocstring,
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/auto_docstring.py in <module>
#      28     _prepare_output_docstrings,
#      29 )
# ---> 30 from .generic import ModelOutput
#      31
#      32
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in <module>
#      49 if is_torch_available():
#      50     # required for @can_return_tuple decorator to work with torchdynamo
# ---> 51     import torch  # noqa: F401
#      52
#      53     from ..model_debugging_utils import model_addition_debugger_context
#
# /usr/local/lib/python3.12/dist-packages/torch/__init__.py in <module>
#     414     if USE_GLOBAL_DEPS:
#     415         _load_global_deps()
# --> 416     from torch._C import *  # noqa: F403
#     417
#     418
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _lock_unlock_module(name)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Если используете ключ из курса, запустите эти ячейки 👇

# %%
from langchain_openai import ChatOpenAI
from getpass import getpass

#course_api_key= "Введите ваш API ключ, полученный в боте курса"
course_api_key = getpass(prompt='Введите ваш API ключ, полученный в боте курса')

# инициализируем языковую модель
llm = ChatOpenAI(api_key=course_api_key, model='gpt-4o-mini',
                base_url="https://aleron-llm.neuraldeep.tech/")
# Out:
# Введите ваш API ключ, полученный в боте курса··········

# %% [markdown]
# ## Задание 3.3.7 🛠️ Кастомные инструменты 🧮

# %%
from math import pi
import math
# Импортируйте tool

# %%
from langchain_core.tools import tool

# %%
# 2 реализованные функции, как пример
@tool
def compute_arc_length(radius, angle_in_degrees):
    """Вычисляет длину дуги по радиусу и углу в градусах"""
    return (angle_in_degrees / 360) * 2 * pi * radius


@tool
def compute_triangle_area(a, b, c):
    """Вычисляет площадь треугольника по длинам его сторон"""
    s = (a + b + c) / 2
    return math.sqrt(s * (s - a) * (s - b) * (s - c))

# %% [markdown]
# Список функций, которые вам нужно реализовать:
#
# - `add_numbers(num1, num2)` - Складывает два числа
# - `convert_meters_to_cm(num)` - Переводит метры в сантиметры
# - `convert_cubic_cm_to_liters(num)` - Переводит кубические сантиметры в литры
# - `compute_rectangle_perimeter(a, b)` - Вычисляет периметр прямоугольника
# - `compute_circle_area(radius)` - Вычисляет площадь круга
# - `compute_cylinder_volume(radius, height)` - Вычисляет объем цилиндра
# - `compute_cube_volume(a)` - Вычисляет объем куба
# - `convert_binary_to_decimal(binary_number: str)` - Переводит число из двоичной системы счисления в десятичную систему счисления
# - `convert_decimal_to_binary(decimal_number)` - Переводит число из десятичной системы счисления в двоичную систему счисления.
# - `get_count_ones(number: str)` - Находит количество единиц в двоичном представлении числа.

# %%
# Реализуйте функции
# Реализуйте остальные функции
@tool
def add_numbers(num1, num2):
    """Складывает два числа"""
    return num1 + num2

@tool
def convert_meters_to_cm(num):
    """Переводит метры в сантиметры"""
    return num * 100

@tool
def convert_cubic_cm_to_liters(num):
    """Переводит кубические сантиметры в литры"""
    return num / 1000

@tool
def compute_rectangle_perimeter(a, b):
    """Вычисляет периметр прямоугольника"""
    return 2 * (a + b)

@tool
def compute_circle_area(radius):
    """Вычисляет площадь круга"""
    return pi * radius**2

@tool
def compute_cylinder_volume(radius, height):
    """Вычисляет объем цилиндра"""
    return pi * radius**2 * height

@tool
def compute_cube_volume(a):
    """Вычисляет объем куба"""
    return a**3

@tool
def convert_binary_to_decimal(binary_number: str):
    """Переводит число из двоичной системы счисления в десятичную систему счисления"""
    return int(binary_number, 2)

@tool
def convert_decimal_to_binary(decimal_number):
    """Переводит число из десятичной системы счисления в двоичную систему счисления."""
    return bin(decimal_number)[2:]

@tool
def get_count_ones(number: str):
    """Находит количество единиц в двоичном представлении числа."""
    return sum([int(x) for x in number])

# %%
# Поместите все написанные функции в tools
tools = [
    compute_arc_length,
    compute_triangle_area,
    add_numbers,
    convert_meters_to_cm,
    convert_cubic_cm_to_liters,
    compute_rectangle_perimeter,
    compute_circle_area,
    compute_cylinder_volume,
    compute_cube_volume,
    convert_binary_to_decimal,
    convert_decimal_to_binary,
    get_count_ones
]

# %%
# Ячейка опциональная, если захотите проверить свои функции - можете раскомментировать.
# ВНИМАНИЕ!!! - проверяются функции до того как будут обёрнуты в декоратор @tool
# Запустите эту ячейку с тестами для проверки написанных функций

# assert add_numbers(-3, -5) == -8, "Ошибка в функции: add_numbers(-3, -5) должно быть -8"
# assert convert_meters_to_cm(2) == 200, "Ошибка в функции: convert_meters_to_cm(2) должно быть 200"
# assert convert_cubic_cm_to_liters(500) == 0.5, "Ошибка в функции: convert_cubic_cm_to_liters(500) должно быть 0.5"
# assert compute_rectangle_perimeter(5, 5) == 20, "Ошибка в функции: compute_rectangle_perimeter(5, 5) должно быть 20"
# assert math.isclose(compute_circle_area(2), 4 * math.pi, rel_tol=1e-5), "Ошибка в функции: compute_circle_area(2) должно быть близко к 4 * pi"
# assert math.isclose(compute_triangle_area(3, 4, 5), 6, rel_tol=1e-5), "Ошибка в функции: compute_triangle_area(3, 4, 5) должно быть 6"
# assert math.isclose(compute_cylinder_volume(2, 3), 12 * math.pi, rel_tol=1e-5), "Ошибка в функции: compute_cylinder_volume(2, 3) должно быть близко к 12 * pi"
# assert compute_cube_volume(3) == 27, "Ошибка в функции: compute_cube_volume(3) должно быть 27"
# assert math.isclose(compute_arc_length(2, 90), math.pi, rel_tol=1e-5), "Ошибка в функции: compute_arc_length(2, 90) должно быть близко к pi"
# assert convert_binary_to_decimal("1101") == 13, "Ошибка в функции: convert_binary_to_decimal('1101') должно быть 13"
# assert convert_decimal_to_binary(13) == "1101", "Ошибка в функции: convert_decimal_to_binary(13) должно быть '1101'"
# assert get_count_ones("1010") == 2, "Ошибка в функции: get_count_ones('1010') должно быть 2"

# %% [markdown]
# ## Задание 3.3.8 🧑‍🎓 Грокаем школьные математические задачки

# %% [markdown]
# Использовав `tools` с предыдущего степа, решите предоставленные примеры и запишите ответ в столбец `answer` (только ответ, во всех задачах это числа - целые или вещественные).

# %%
import pandas as pd
from tqdm import tqdm


df = pd.read_csv("https://stepik.org/media/attachments/lesson/1110884/custom_math_tools.csv")
df.head()
# Out:
#                                                 task
# 0  Периметр прямоугольника со сторонами 1.5 м и 2...
# 1  Найди сумму площадей круга с радиусом 5 см и к...
# 2  Переведи числа 20 и 32 из десятичной в двоичну...
# 3  Переведи числа из двоичной системы счисления 1...
# 4  Найди объем цилиндра с радиусом 10 см и высото...

# %%
from langchain_core.messages import HumanMessage

# %%
# !pip install langchain-experimental -q

# %%
import pandas as pd
from langchain.agents.agent_types import AgentType
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

# %%
from langchain.agents import create_react_agent, AgentExecutor

# %%
from langchain.agents import AgentExecutor, create_tool_calling_agent
from langchain_core.prompts import PromptTemplate

# Правильный промт для create_tool_calling_agent
prompt = ChatPromptTemplate.from_messages([
    ("system", "Ты — математический ассистент. Решай задачи, используя доступные инструменты. Отвечай ТОЛЬКО числом или выражением. Если число дробное — округли до 2 знаков после запятой."),
    ("human", "{input}"),
    MessagesPlaceholder("agent_scratchpad"),  # <-- ОБЯЗАТЕЛЬНО для tool-calling agent
])

# Создаем агента
agent = create_tool_calling_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)  # verbose=True если хотите видеть логи

# Загружаем задачи
df = pd.read_csv("https://stepik.org/media/attachments/lesson/1110884/custom_math_tools.csv")

# %%
# Решаем каждую задачу
answers = []
for task in tqdm(df['task']):
    try:
        result = agent_executor.invoke({"input": task})
        answer = result["output"]
        # Пробуем конвертировать в float
        float_answer = float(answer)
        answers.append(round(float_answer, 2))
    except (ValueError, TypeError, Exception):
        # Если не получилось — добавляем None
        answers.append(None)
# Out:
# 100%|██████████| 10/10 [00:56<00:00,  5.61s/it]

# %%
df
# Out:
#                                                 task
# 0  Периметр прямоугольника со сторонами 1.5 м и 2...
# 1  Найди сумму площадей круга с радиусом 5 см и к...
# 2  Переведи числа 20 и 32 из десятичной в двоичну...
# 3  Переведи числа из двоичной системы счисления 1...
# 4  Найди объем цилиндра с радиусом 10 см и высото...
# 5  Найди длину дуги окружности с радиусом 20 м, о...
# 6  Переведи десятичное число 1524 в двоичную сист...
# 7  Найти объем куба со стороной 5 см, затем перев...
# 8  Стороны треугольника соответственно равны 30 с...
# 9  Найди объемы двух цилиндров с радиусами 8 см и...

# %%
# Добавляем ответы в DataFrame
df['answer'] = answers

# Сохраняем результат
df[['task', 'answer']].to_csv("3.3.8_solution.csv", index=False)

# %%
df
# Out:
#                                                 task      answer
# 0  Периметр прямоугольника со сторонами 1.5 м и 2...      700.00
# 1  Найди сумму площадей круга с радиусом 5 см и к...      106.81
# 2  Переведи числа 20 и 32 из десятичной в двоичну...        3.00
# 3  Переведи числа из двоичной системы счисления 1...      901.00
# 4  Найди объем цилиндра с радиусом 10 см и высото...        9.42
# 5  Найди длину дуги окружности с радиусом 20 м, о...     2094.40
# 6  Переведи десятичное число 1524 в двоичную сист...         NaN
# 7  Найти объем куба со стороной 5 см, затем перев...  1111101.00
# 8  Стороны треугольника соответственно равны 30 с...      600.00
# 9  Найди объемы двух цилиндров с радиусами 8 см и...       15.33
